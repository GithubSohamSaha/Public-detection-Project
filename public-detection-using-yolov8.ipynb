# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.7/793.7 kB 11.9 MB/s eta 0:00:00 0:00:01
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
model.train(data="/kaggle/input/public-detection-dataset-for-yolov8/data.yaml", epochs=5) 
#esults = model("https://ultralytics.com/images/bus.jpg")  # predict on an image
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# Load the trained model
net = cv2.dnn.readNetFromDarknet("yolov8.cfg", "yolov8.weights")

# Load an image
img = cv2.imread("image.jpg")

# Get the detections
outputs = net.forward(img)

# Draw the detections on the image
for output in outputs:
    for detection in output:
        scores = detection[5:]
        class_id = np.argmax(scores)
        confidence = scores[class_id]
        if confidence > 0.5 and class_id == 0:  # Filter by class ID and confidence
            x, y, w, h = detection[0:4]
            cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

# Display the output
plt.imshow(img)
plt.show()
